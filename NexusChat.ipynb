# %% [markdown]
# <a href="https://colab.research.google.com/github/PRAVEEN-CS33/NexusChat/blob/main/NexusChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyngrok==4.1.1
# !pip install flask_ngrok
# !ngrok authtoken "2MbT6ft3bDVHAVnCvSfGW5xrZNR_3BEUywuNRUaCgimkguy9G" 
# !pip install flask-cors

# %% [markdown]
# ### **Dataset**

# %%
intents ={
    "intents": [
      {
        "tag": "greeting",
        "patterns": [
          "Hi",
          "Hey",
          "How are you",
          "Is anyone there?",
          "Hello",
          "Good day",
          "Welcome"
        ],
        "responses": [
          "Hey :-)",
          "Hello, thanks for visiting",
          "Hi there, what can I do for you?",
          "Hi there, how can I help?",
          "Welcome! How can I help you today?"
        ]
      },
      {
        "tag": "thanks",
        "patterns": ["Thanks", "Thank you", "That's helpful", "Thank's a lot!","Thankyou"],
        "responses": ["Happy to help!", "Any time!", "My pleasure"]
      },
      {
        "tag": "Morning",
        "patterns": [
          "GoodMorning",
          "Good Morning",
          "Morning"
        ],
        "responses": [
          "Good morning! How can I help you today?"
        ]
      },
      {
        "tag": "goodbye",
        "patterns": ["Bye", "See you later", "Goodbye"],
        "responses": [
          "See you later, thanks for visiting",
          "Have a nice day",
          "Bye! Come back again soon."
        ]
      },
      {
        "tag": "department",
        "patterns": [
          "Tell about the departments in Tamilnadu",
          "What are the departments available?",
          "What are the departments available in Tamilnadu?",
          "departments available",
          "departments in Tamilnadu",
          "departments in TN"
        ],
        "responses": [
          "Health and Family Welfare Department or School Education Departments"
        ]
      },
      {
        "tag": "schemes",
        "patterns": [
            "explain me some schemes",
          "Schemes in Health and Family Welfare Department",
          "Health and Family Welfare Department Schemes",
          "What are the schemes available in Health and Family Welfare Department?",
          "Schemes of Health and Family Welfare Department"],
        "responses": [
          "Janani Suraksha Yojana , Janani Shishu Suraksha Karyakram , Dr. Muthulakshmi Reddy Maternity Benefit Scheme (MRMBS) , Girl child protection scheme"
        ]
      },
      {
        "tag": "Janani Suraksha Yojana",
        "patterns": [
          "Tell about Janani Suraksha Yojana",
          "Tell about JSY",
          "what is Janani Suraksha Yojana scheme?",
          "what is JSY?",
          "About Janani Suraksha Yojana",
          "Janani Suraksha Yojana",
          "JSY"
        ],
        "responses": [
          "Janani Suraksha Yojana (JSY) is a safe motherhood intervention scheme under the National Health Mission in India , It aims to reduce maternal and neonatal mortality by promoting institutional delivery among pregnant women, especially those who are poor and for more information visit https://www.nhm.tn.gov.in/en/nhm-programsrmncha/janani-shishu-suraksha-karyakram-jssk"
        ]
      },
      {
        "tag": "eligibility for Janani Suraksha Yojana",
        "patterns": [
          "Eligible for Janani Suraksha Yojana",
          "Eligible for JSY",
          "JSY Eligibility",
          "Janani Suraksha Yojana Eligibility",
          "who are Eligible for Janani Suraksha Yojana scheme?",
          "who are eligible for JSY?"
        ],
        "responses": [
          "Pregnant women who fall below the poverty line, whether in rural or urban areas, are eligible for Janani Suraksha Yojana"
        ]
      },
      {
        "tag": "Required documents for JSY",
        "patterns": [
          "Required documents for Janani Suraksha Yojana scheme",
          "Required documents for JSY scheme",
          "What are the documents required for Janani Suraksha Yojana scheme?",
          "What are the documents required for JSY?",
          "documents required for Janani Suraksha Yojana scheme",
          "documents required for JSY",
          "documents for Janani Suraksha Yojana scheme",
          "documents for JSY",
          "JSY documents",
          "Janani Suraksha Yojana documents scheme"],
        "responses": [
          "Required documents for JSY scheme is Aadhar card , Address Proof, Bank passbook , Janani Suraksha Yojana card"
        ]
      },
      {
        "tag": "Apply for JSY",
        "patterns": [
          "How to apply for Janani Suraksha Yojana scheme ?",
          "How to apply for JSY?",
          "apply for Janani Suraksha Yojana scheme",
          "apply for JSY",
          "apply Janani Suraksha Yojana scheme ?",
          "apply JSY",
          "where to apply for Janani Suraksha Yojana scheme"
        ],
        "responses": [
          "To apply for Janani Suraksha Yojana online by visiting the official website of JSY(https://nhm.gov.in/index1.php?lang=1&level=3&lid=309&sublinkid=841) or by visiting nearby public healthcare center , You will need to provide your RCH ID, category, applicant name, husband name, gender, Aadhaar number or virtual ID, date of birth, age, mobile number and other relevant information."
        ]
      },
      {
        "tag": "Benefits of JSY",
        "patterns": [
          "Benefits of JSY",
          "Benifits of Janani Suraksha Yojana",
          "Janani Suraksha Yojana benifits",
          "JSY benifits",
          "what are the benifits of Janani Suraksha Yojana scheme?",
          "What are the benifits of JSY?"
        ],
        "responses": [
          "Janani Suraksha Yojana provides cash assistance to eligible pregnant women who give birth in a government or accredited private health facility , The amount of financial assistance provided is Rs. 500/- per birth up to two live births for pregnant women who have attained 19 years of age and belong to the National Maternity Benefit Scheme (NMBS)."
        ]
      },
      {
        "tag": "link for JSY",
        "patterns": [
          "link to apply for Janani Suraksha Yojana scheme",
          "link to apply for JSY",
          "More information about Janani Suraksha Yojana scheme",
          "More information about JSY",
          "Janani Suraksha Yojana scheme link",
          "JSY scheme link",
          "JSY link"
        ],
        "responses": [
          "visit https://nhm.gov.in/index1.php?lang=1&level=3&lid=309&sublinkid=841 to get more information about this scheme."  
        ]
      },
      {
        "tag": "JSSK",
        "patterns": [
          "Tell about Janani Shishu Suraksha Karyakram scheme",
          "Tell about JSSK",
          "what is Janani Shishu Suraksha Karyakram scheme?",
          "what is JSSK?",
          "About Janani Shishu Suraksha Karyakram scheme",
          "About JSSK",
          "Janani Shishu Suraksha Karyakram",
          "JSSK"
        ],
        "responses": [
          "The Government of India introduced the Janani Shishu Suraksha Karyakram (JSSK) programme, which grants all expectant mothers giving birth in public health facilities the right to an entirely free delivery, including a Caesarean section and The programme intends to remove out-of-pocket costs that expectant mothers and unwell babies suffer when utilising services at public health institutions."
        ]
      },
      {
        "tag": "eligibility for Janani Shishu Suraksha Karyakram",
        "patterns": [
          "Eligible for Janani Shishu Suraksha Karyakram",
          "Eligible for JSSK",
          "JSSK Eligibility",
          "Janani Shishu Suraksha Karyakram Eligibility",
          "who are Eligible for Janani Shishu Suraksha Karyakram?",
          "who are eligible for JSSK?"
        ],
        "responses": [
          "Pregnant women who belong to below poverty line households and are at least 19 years old are eligible for the Janani Shishu Suraksha Karyakram and The scheme aims to benefit pregnant women who access government health facilities."  
        ]
      },
      {
        "tag": "Required documents for JSSK",
        "patterns": [
          "Required documents for  Janani Shishu Suraksha Karyakram scheme",
          "Required documents for JSSK scheme",
          "What are the documents required for  Janani Shishu Suraksha Karyakram scheme?",
          "What are the documents required for JSSK?",
          "documents required for  Janani Shishu Suraksha Karyakram scheme",
          "documents required for JSSK",
          "documents for  Janani Shishu Suraksha Karyakram scheme",
          "documents for JSSK",
          "JSSK documents",
          "Janani Shishu Suraksha Karyakram documents"],
        "responses": [
          "Required documents for JSSK scheme is Aadhar card , Address Proof, Bank passbook"
        ]
      },
      {
        "tag": "Apply for JSSK",
        "patterns": [
          "How to apply for  Janani Shishu Suraksha Karyakram?",
          "How to apply for JSSK?",
          "apply for Janani Shishu Suraksha Karyakram scheme",
          "apply for JSSK",
          "apply Janani Shishu Suraksha Karyakram scheme?",
          "apply JSSK",
          "where to apply for Janani Shishu Suraksha Karyakram scheme"
        ],
        "responses": [
          "To apply for Janani Shishu Suraksha Karyakram online by visiting the official website of JSSK(https://www.nhm.tn.gov.in/en/nhm-programsrmncha/janani-shishu-suraksha-karyakram-jssk) or by visiting nearby public health centers and You will need to provide your name, husband name, gender, Aadhaar number or virtual ID, date of birth, age, mobile number and other relevant information."
        ]
      },
      {
        "tag": "Benefits of JSSK",
        "patterns": [
          "Benefits of JSSK",
          "Benifits of Janani Shishu Suraksha Karyakram",
          "Janani Shishu Suraksha Karyakram benifits",
          "JSSK benifits",
          "what are the benifits of Janani Shishu Suraksha Karyakram scheme?",
          "What are the benifits of JSSK?"
        ],
        "responses": [
          "An initiative called Janani Shishu Suraksha Karyakram (JSSK) aims to offer pregnant women, caesarean patients, and unwell newborns (up to 30 days after birth) totally free and cashless care in government health facilities in both rural and urban areas , All pregnant women who give birth at public health facilities are entitled to completely free deliveries, including caesarean sections, free drugs and supplies, free diagnostics, free blood donation, exemption from user fees, and free transportation from their homes to the facility."  
        ]
      },
      {
        "tag": "link for JSSK",
        "patterns": [
          "link to apply for Janani Shishu Suraksha Karyakram scheme",
          "link to apply for JSSK",
          "More information about Janani Shishu Suraksha Karyakram scheme",
          "More information about JSSK",
          "Janani Shishu Suraksha Karyakram scheme link",
          "JSSK scheme link",
          "JSSK link"
        ],
        "responses": [
          "Visit https://www.nhm.tn.gov.in/en/nhm-programsrmncha/janani-shishu-suraksha-karyakram-jssk to get more information about this scheme."  
        ]
      },
      {
        "tag": "Dr. Muthulakshmi Reddy Maternity Benefit Scheme (MRMBS)",
        "patterns": [
          "Tell about Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "Tell about MRMBS",
          "what is Dr. Muthulakshmi Reddy Maternity Benefit Scheme?",
          "what is MRMBS?",
          "About Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "MRMBS"
        ],
        "responses": [
          "The Dr. Muthulakshmi Reddy Maternity Benefit Scheme (MRMBS) is a programme that offers low-income expectant women cash support. The programme was renamed Dr. Muthulakshmi Reddy Maternity Benefit Program from National Maternity Benefit Scheme."  
        ]
      },
      {
        "tag": "eligibility for MRMBS",
        "patterns": [
          "Eligible for Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "Eligible for MRMBS",
          "MRMBS Eligibility",
          "Dr. Muthulakshmi Reddy Maternity Benefit Scheme Eligibility",
          "who are Eligible for Dr. Muthulakshmi Reddy Maternity Benefit Scheme?",
          "who are eligible for MRMBS?"
        ],
        "responses": [
          "\\The pregnant mother should be of age 19 years and above , Should be a citizen of India and permanent resident of Tamil Nadu and Should have completed 19 yrs of age , The financial background of the pregnant woman should be below poverty line ."
        ]
      },
      {
        "tag": "Required documents for MRMBS",
        "patterns": [
          "Required documents for Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "Required documents for MRMBS scheme",
          "What are the documents required for Dr. Muthulakshmi Reddy Maternity Benefit Scheme?",
          "What are the documents required for MRMBS?",
          "documents required for Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "documents required for MRMBS",
          "documents for Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "documents for MRMBS",
          "MRMBS documents",
          "Dr. Muthulakshmi Reddy Maternity Benefit Scheme documents"],
        "responses": [
          "Required documents for MRMBS is Aadhar card , Address Proof, Bank passbook ,Voter ID or Ration card."
        ]
      },
      {
        "tag": "Apply for MRMBS",
        "patterns": [
          "How to apply for Dr. Muthulakshmi Reddy Maternity Benefit Scheme?",
          "How to apply for MRMBS?",
          "apply for Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "apply for MRMBS",
          "apply Dr. Muthulakshmi Reddy Maternity Benefit Scheme ?",
          "apply MRMBS",
          "where to apply for Dr. Muthulakshmi Reddy Maternity Benefit Scheme"
        ],
        "responses": [
          "To apply for Dr. Muthulakshmi Reddy Maternity Benefit Scheme, the pregnant mother should register her pregnancy before 12 weeks with the VHN / UHN or she should have pre-registration of pregnancy in PICME" 
        ]
      },
      {
        "tag": "Benefits of MRMBS",
        "patterns": [
          "Benefits of MRMBS",
          "Benifits of Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "MRMBS benifits",
          "what are the benifits of Dr. Muthulakshmi Reddy Maternity Benefit Scheme?",
          "What are the benifits of MRMBS?"
        ],
        "responses": [
          "Dr. Muthulakshmi Reddy Maternity Benefit Scheme provides financial assistance to poor pregnant mothers in India In accordance with the terms of the G.O.(Ms) No. 184 dated on 11.09, impoverished pregnant women are eligible to receive Rs. 1000/month for 6 months starting in the seventh month of pregnancy."
        ]
      },
      {
        "tag": "link for MRMBS",
        "patterns": [
          "link to apply for Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "link to apply for MRMBS",
          "More information about Dr. Muthulakshmi Reddy Maternity Benefit Scheme",
          "More information about MRMBS",
          "Dr. Muthulakshmi Reddy Maternity Benefit Scheme link",
          "MRMBS scheme link",
          "MRMBS link"
        ],
        "responses": [
          "Visit https://krishnagiri.nic.in/scheme/dr-muthulakshmi-maternity-benefit-scheme/ to get more information about this scheme."  
        ]
      },
      {
        "tag": "Girl child protection scheme",
        "patterns": [
          "Tell about Girl child protection scheme",
          "what is Girl child protection scheme?",
          "About Girl child protection scheme",
          "Girl child protection scheme"
        ],
        "responses": [
          "The Chief Minister's Girl Child Protection Scheme is aimed at preventing gender discrimination by empowering and protecting the rights of girl children through direct investment from the government and The Scheme's objectives are to increase girl students enrollment and attendance in school and to guarantee that they complete at least an intermediate level of education." 
        ]
      },
      {
        "tag": "eligibility for Girl child protection scheme",
        "patterns": [
          "Eligible for Girl child protection scheme",
          "CM'S Girl child protection scheme Eligibility",
          "Girl child protection scheme Eligibility",
          "who are eligible for Girl child protection scheme?",
          "who are all eligible for Girl child protection scheme?"
        ],
        "responses": [
          "\\To be eligible for Chief Minister's Girl Child Protection Scheme, The girl child should appear for 10th standard public examination , The family should have two female child and no male child , The girl child must be enrolled in an educational institution" 
        ]
      },
      {
        "tag": "Required documents for Girl child protection scheme",
        "patterns": [
          "Required documents for Girl child protection scheme",
          "What are the documents required for Girl child protection scheme?",
          "documents required for Girl child protection scheme",
          "documents for Girl child protection scheme",
          "Girl child protection scheme documents"],
        "responses": [
          "Aadhar card , Bank passbook , Ration card , income certificate , Age certificate , Nativity Certificate"
        ]
      },
      {
        "tag": "Apply for Girl child protection scheme",
        "patterns": [
          "How to apply for Girl child protection scheme?",
          "apply for Girl child protection scheme",
          "apply Girl child protection scheme",
          "where to apply for Girl child protection scheme?",
          "Girl child protection scheme apply"
        ],
        "responses": [
          "To apply for Chief Minister's Girl Child Protection Scheme, citizens can apply through eSeva or visit the district social welfare office and Applicants should apply with relevant documents such as Income Certificate, Nativity Certificate, No male child Certificate, Birth Certificate of Girl Childrens"  
        ]
      },
      {
        "tag": "Benefits of Girl child protection scheme",
        "patterns": [
          "Benifits of Girl child protection scheme",
          "what are the benifits of Girl child protection scheme?",
          "Girl child protection scheme benifits"
        ],
        "responses": [
          "The Chief Minister's Girl Child Protection Program strives to ensure that all girls receive an education that is at least at the intermediate level and to encourage their enrollment and retention in school and The programme urges girls to wait until they are 18 years old before getting married."
        ]
      },
      {
        "tag": "link for Girl child protection scheme",
        "patterns": [
          "More information about Girl child protection scheme",
          "Girl child protection scheme link"
        ],
        "responses": [
          "https://chennai.nic.in/old-welfare/"  
        ]
      }
    ]
  }

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/tamilnadu-state-scheme.xlsx')
print(df['Scheme'].unique())
print(df['Scheme Description'].unique())
# Out:
# ['Amma Two-Wheeler Scheme' 'Solar Powered Green House Scheme'
#  "Chief Minister's Comprehensive Health Insurance Scheme"
#  'Supply of Text Books to Students' 'Free Supply of Uniforms to Students']
# ['Amma Two-Wheeler Scheme was launched in February 2018 for the development of working women in Tamil Nadu from poorer sections of the society. Under this scheme, eligible applicants can avail discount on two-wheeler purchase of up to a maximum of 50% or Rs.25,000 whichever is lower. It also provides three-wheeled retrofitted two-wheelers for differently-abled women.'
#  "The Chief Minister’s Solar Powered Green House Scheme (CMSPGHS) was launched in 2011-12. It is a flagship scheme of Government of Tamil Nadu, aimed at providing Solar-Powered Green Houses for those living “Below Poverty Line” in rural areas. The scheme promotes green energy and 'Housing for all' with Solar Powered Home Lighting Systems."
# ...

# %%
print(intents["intents"])
# Out:
# [{'tag': 'greeting', 'patterns': ['Hi', 'Hey', 'How are you', 'Is anyone there?', 'Hello', 'Good day', 'Welcome'], 'responses': ['Hey :-)', 'Hello, thanks for visiting', 'Hi there, what can I do for you?', 'Hi there, how can I help?', 'Welcome! How can I help you today?']}, {'tag': 'thanks', 'patterns': ['Thanks', 'Thank you', "That's helpful", "Thank's a lot!", 'Thankyou'], 'responses': ['Happy to help!', 'Any time!', 'My pleasure']}, {'tag': 'Morning', 'patterns': ['GoodMorning', 'Good Morning', 'Morning'], 'responses': ['Good morning! How can I help you today?']}, {'tag': 'goodbye', 'patterns': ['Bye', 'See you later', 'Goodbye'], 'responses': ['See you later, thanks for visiting', 'Have a nice day', 'Bye! Come back again soon.']}, {'tag': 'department', 'patterns': ['Tell about the departments in Tamilnadu', 'What are the departments available?', 'What are the departments available in Tamilnadu?', 'departments available', 'departments in Tamilnadu', 'departments in TN'], 'response
# ...

# %% [markdown]
# ### **NLTK_utils**

# %%
# !pip install numpy
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
import numpy as np
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()

def tokenize(data):
  return word_tokenize(data)

def stem(word):
  return stemmer.stem(word.lower())

def bag_of_words(tokenized_sentence, all_word):
  tokenized_sentence = [stem(w) for w in tokenized_sentence]
  bag = np.zeros(len(all_word),dtype=np.float32)
  for idx, word in enumerate(all_word):
    if word in tokenized_sentence:
      bag[idx] = 1.0
  return bag

# %% [markdown]
# ### **Model**

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
import torch.nn as nn

class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size) 
        self.l2 = nn.Linear(hidden_size, hidden_size) 
        self.l3 = nn.Linear(hidden_size, num_classes)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        out = self.relu(out)
        out = self.l3(out)
        return out

# %% [markdown]
# ### **Training**

# %%
# import json
import numpy as np
# from botnlp import tokenize,stem,bag_of_words

import torch
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader

# from model import NeuralNet

# with open('intents.json','r') as f:
#     intents = json.load(f)

all_words = []
tags = []
xy = []
for intent in intents['intents']:
    tag = intent['tag']
    tags.append(tag)
    for pattern in intent['patterns']:
        w = tokenize(pattern)
        all_words.extend(w)
        xy.append((w,tag))
ignore_words = ['!','@','#','$','%','^','&','*','(',')','?','/']
all_words = [stem(w) for w in all_words if w not in ignore_words]
all_words = sorted(set(all_words))
tag = sorted(set(tags))

x_trian = []
y_train = []

for (pattern_sentence,tag) in xy:
    bag  = bag_of_words(pattern_sentence, all_words) 
    x_trian.append(bag)

    label = tags.index(tag)
    y_train.append(label)

x_trian = np.array(x_trian)
y_train = np.array(y_train)

class ChatDataset(Dataset):
    def __init__(self):
        self.n_samples = len(x_trian)
        self.x_data = x_trian
        self.y_data = y_train
    # Dataset[idx]
    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]
    
    def __len__(self):
        return self.n_samples

#hypperparameters
batch_size = 8
input_size = len(x_trian[0])
hidden_size = 8
output_size = len(tags)
learning_rate = 0.001
num_epochs = 1000

dataset = ChatDataset()
train_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True, num_workers=2)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NeuralNet(input_size, hidden_size, output_size).to(device)

#loss & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    for(words, labels) in train_loader:
        words = words.to(device)
        labels = labels.to(device)

        #forward
        output = model(words)
        loss = criterion(output, labels)

        #backward and optimizer step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    if(epoch +1) % 100 == 0:
        print(f'epoch {epoch+1}/{num_epochs}, loss={loss.item():.4f}')
print(f'final loss, loss={loss.item():.4f}')

data = {
"model_state": model.state_dict(),
"input_size": input_size,
"hidden_size": hidden_size,
"output_size": output_size,
"all_words": all_words,
"tags": tags
}

FILE = "data.pth"
torch.save(data, FILE)

print('training complete.file saved')

# %% [markdown]
# ### **Chat**

# %%
import random
# import json
import torch
# from model import NeuralNet
# from nltk_utils import bag_of_words, tokenize

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# with open('intents.json', 'r') as json_data:
#     intents = json.load(json_data)

FILE = "data.pth"
data = torch.load(FILE)

input_size = data["input_size"]
hidden_size = data["hidden_size"]
output_size = data["output_size"]
all_words = data['all_words']
tags = data['tags']
model_state = data["model_state"]

model = NeuralNet(input_size, hidden_size, output_size).to(device)
model.load_state_dict(model_state)
model.eval()

bot_name = "SCHEMEBOT"

def get_response(msg):
    sentence = tokenize(msg)
    X = bag_of_words(sentence, all_words)
    X = X.reshape(1, X.shape[0])
    X = torch.from_numpy(X).to(device)

    output = model(X)
    _, predicted = torch.max(output, dim=1)

    tag = tags[predicted.item()]

    probs = torch.softmax(output, dim=1)
    prob = probs[0][predicted.item()]
    
    if prob.item() > 0.75:
        for intent in intents['intents']:
            if tag == intent["tag"]:
                return random.choice(intent['responses'])
    
    return "I do not understand..."


# if __name__ == "__main__":
#     print("Let's chat with schemeBot ):")
#     print(f"SCHEMEBOT : Hello,how can i help you..?")
#     while True:
#         sentence = input("YOU : ")
#         if sentence == "tata":
#           print("SCHEMEBOT : TATA,na poitu varen")
#           break

#         resp = get_response(sentence)
#         print(f"SCHEMEBOT : {resp}")

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask, request, jsonify
from flask_cors import CORS, cross_origin

app = Flask(__name__)
run_with_ngrok(app)
CORS(app)

@app.route('/', methods=['POST', 'GET'])
@cross_origin(origins=['http://localhost:3000', 'https://example.com'])

def predict():
    data = request.json.get('data')
    res = get_response(data)
    return jsonify({ 'text': res })
    
app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://538a-34-70-226-154.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:46:53] "OPTIONS / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:46:54] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:47:20] "OPTIONS / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:47:20] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:49:10] "OPTIONS / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:49:11] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:49:21] "OPTIONS / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Mar/2023 14:49:21] "POST / HTTP/1.1" 200 -
# ...

# %%
const handleSubmit = async (event) => {
    event.preventDefault();
    try {
      const response = await axios.post('http://17ea-34-23-11-227.ngrok.io/', {data: inputText});
      setOutputText(response.data.text);
    } catch (error) {
      console.error(error);
    }
};

# %% [markdown]
# ### Optical character recognition(**OCR**)

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.2/619.2 KB 44.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 15.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# ...

# %%
from google.colab import files
import cv2
import easyocr
import os
import json

# %%
uploaded = files.upload()
filename = next(iter(uploaded))
# filepath = os.path.join(os.getcwd(),filename)
# print(filename)
# print(filepath)
# Out:
#      <input type="file" id="files-811c4b3d-4f45-4546-ab13-11807f4a5ee1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-811c4b3d-4f45-4546-ab13-11807f4a5ee1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display the image
from IPython.display import Image
Image(filename)

# %%
image = cv2.imread(filename)
reader = easyocr.Reader(['en'])
results = reader.readtext(image)
print(results)
result_text = os.path.join(os.getcwd(),'result_text.te')
output = {'text':[]}
for result in results:
  output['text'].append(result[1])
with open('output_text.json','w') as outputfile:
  json.dump(output,outputfile)
print(f"file saved @ {os.path.join(os.getcwd(),'output_text.json')}")

# %%
print(output)
print(results)
# Out:
# {'text': ['The Acme Tennis Ball Company is designing', 'new box to ship its products. The marketing', 'departmen', 'wants', 'triangular box that can hold', 'balls, as in the illustration below: The balls fit', 'exactly inside the boxjust touching all three walls and the end caps of the container. All 3 walls of', 'the box are the same size (equilateral triangle). Assume', 'tennis ball is', 'cm in diameter, and ignore', 'the thickness of the box material What will be the length and breadth of the material used to make', 'the box? Write', 'program that finds the measure of', 'side of the box:', 'Program must also display the', 'length and breadth of the materia', 'used to make the triangular box:', 'Afo-', 'cumic', 'Mjnol', 'Ya?', "'penmeler 0l Equnaterltnangle", '(0+2+0/ 2', 'Rudius 0f inscrbed cIrcle', 'Af8, ol cqullntoml inanol-', 'Scmi Dcrmcicn 0i squllatetal Wranol']}
# ...

# %% [markdown]
# ## **Document_verification**

# %%
# !pip install tensorflow

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

# %%
#data loading
x_train = np.loadtxt('/content/drive/MyDrive/Colab Notebooks/input.csv', delimiter = ',')
y_train = np.loadtxt('/content/drive/MyDrive/Colab Notebooks/labels.csv', delimiter = ',')
x_test= np.loadtxt('/content/drive/MyDrive/Colab Notebooks/input_test.csv', delimiter = ',')
y_test = np.loadtxt('/content/drive/MyDrive/Colab Notebooks/labels_test.csv', delimiter = ',')

# %%
# reshaping the images as 150x150x3
x_train = x_train.reshape(len(x_train), 100, 100, 3)
y_train = y_train.reshape(len(y_train), 1)

x_test = x_test.reshape(len(x_test), 100, 100, 3)
y_test = y_test.reshape(len(y_test), 1)

x_train /= 255
y_train /= 255

# %%
print(x_train.shape)
x_train[1,:]
# Out:
# (2000, 100, 100, 3)
# array([[[0.51372549, 0.50196078, 0.52941176],
#         [0.62745098, 0.61568627, 0.64313725],
#         [0.77647059, 0.75294118, 0.8       ],
#         ...,
#         [0.98039216, 0.97647059, 0.96862745],
#         [1.        , 1.        , 0.99215686],
#         [0.98039216, 0.97647059, 0.96078431]],
#
#        [[0.54901961, 0.5372549 , 0.56470588],
#         [0.49803922, 0.48627451, 0.51372549],
#         [0.47058824, 0.44705882, 0.48627451],
#         ...,
#         [0.98431373, 0.99215686, 0.98823529],
#         [0.99607843, 1.        , 0.99215686],
#         [0.99607843, 1.        , 0.98431373]],
#
#        [[0.8       , 0.79215686, 0.81176471],
#         [0.73333333, 0.7254902 , 0.74509804],
#         [0.57647059, 0.55686275, 0.58039216],
#         ...,
#         [0.97647059, 1.        , 1.        ],
#         [0.93333333, 0.96862745, 0.94901961],
#         [0.90980392, 0.94509804, 0.9254902 ]],
#
#        ...,
#
# ...

# %%
idx = random.randint(0, len(y_train))
plt.imshow( x_train[idx, :])
# plt.show()

# %% [markdown]
# **Model**

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (100, 100, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(
    loss = 'binary_crossentropy', 
    optimizer = 'adam', 
    metrics = ['accuracy']
)

# %% [markdown]
# **Training**

# %%
model.fit(x_train, y_train, epochs = 10, batch_size = 64)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 32s 965ms/step - loss: 0.0430 - accuracy: 0.5000
# Epoch 2/10
# 32/32 [==============================] - 33s 1s/step - loss: 0.0154 - accuracy: 0.5000
# Epoch 3/10
# 32/32 [==============================] - 36s 1s/step - loss: 0.0144 - accuracy: 0.5000
# Epoch 4/10
# 32/32 [==============================] - 32s 1s/step - loss: 0.0143 - accuracy: 0.5000
# Epoch 5/10
# 32/32 [==============================] - 31s 979ms/step - loss: 0.0141 - accuracy: 0.5000
# Epoch 6/10
# 32/32 [==============================] - 33s 1s/step - loss: 0.0140 - accuracy: 0.5000
# Epoch 7/10
# 32/32 [==============================] - 31s 980ms/step - loss: 0.0140 - accuracy: 0.5000
# Epoch 8/10
# 32/32 [==============================] - 32s 1s/step - loss: 0.0139 - accuracy: 0.5000
# Epoch 9/10
# 32/32 [==============================] - 32s 991ms/step - loss: 0.0138 - accuracy: 0.5000
# Epoch 10/10
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 13/13 [==============================] - 2s 113ms/step - loss: 401.6257 - accuracy: 0.5000
# [401.625732421875, 0.5]

# %% [markdown]
# **Predition**

# %%
index = random.randint(0, len(y_test))
plt.imshow(x_train[index, :])
plt.show()
#y_pred
result = model.predict(x_test[index, :].reshape(1, 100, 100, 3))
print(result)
result = result < 0.5
print(result)
if(result):
  print("dog")
else:
  print("cat")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# [[0.]]
# [[ True]]
# dog
